# %%
#install pandas and scikit-learn
#install matplotlib and joblib
#train and test modal
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.utils import shuffle
data = pd.read_csv('dataset.csv')
data = shuffle(data)
data
# Out:
#      label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 457      9       0       0       0       0       0       0       0       0
# 60       1       0       0       0       0       0       0       0       0
# 162      3       0       0       0       0       0       0       0       0
# 433      8       0       0       0       0       0       0       0       0
# 90       1       0       0       0       0       0       0       0       0
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 249      4       0       0       0       0       0       0       0       0
# 52       1       0       0       0       0       0       0       0       0
# 15       0       0       0       0       0       0       0       0       0
# 201      4       0       0       0       0       0       0       0       0
# 406      8       0       0       0       0       0       0       0       0
#
#      pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 457       0  ...         0         0         0         0         0         0
# 60        0  ...         0         0         0         0         0         0
# 162       0  ...         0         0         0         0         0         0
# 433       0  ...         0         0         0         0         0         0
# 90        0  ...         0         0         0         0         0         0
# ..      ...  ...       ...       ...       ...       ...       ...       ...
# 249       0  ...         0         0         0         0         0         0
# 52        0  ...         0         0         0         0         0         0
# 15        0  ...         0         0         0         0         0         0
# 201       0  ...         0         0         0         0         0         0
# 406       0  ...         0         0         0         0         0         0
#
#      pixel780  pixel781  pixel782  pixel783
# 457         0         0         0         0
# 60          0         0         0         0
# 162         0         0         0         0
# 433         0         0         0         0
# 90          0         0         0         0
# ..        ...       ...       ...       ...
# 249         0         0         0         0
# 52          0         0         0         0
# 15          0         0         0         0
# 201         0         0         0         0
# 406         0         0         0         0
#
# [500 rows x 785 columns]

# %%
x = data.drop(["label"],axis = 1)
y = data["label"]

# %%
idx = 49
img = x.loc[idx].values.reshape(28,28)
print(y[idx])
plt.imshow(img)
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y, test_size = 0.2)

# %%
import joblib
from sklearn.svm import SVC
classifier=SVC(kernel="linear",random_state=6)
classifier.fit(train_x,train_y)
joblib.dump(classifier,"model/digit_classifier")
# Out:
# ['model/digit_classifier']

# %%
#calculate accuracy
from sklearn import metrics
prediction = classifier.predict(test_x)
print("accuracy:",metrics.accuracy_score(prediction,test_y))
# Out:
# accuracy: 0.96
